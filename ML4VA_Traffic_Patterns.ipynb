# %% [markdown]
# <a href="https://colab.research.google.com/github/anissapatel/ML4VA/blob/main/ML4VA_Traffic_Patterns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split

import numpy as np
np.random.seed(42)

import matplotlib.pyplot as plt

# %%
import requests
import geopandas as gpd
import pandas as pd

# Step 1: Define the API URL
url = "https://services.arcgis.com/p5v98VHDX9Atv3l7/arcgis/rest/services/CrashData_test/FeatureServer/0/query?outFields=*&where=1%3D1&f=geojson"

# Step 2: Fetch the data from the API
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    print("Data fetched successfully!")
    # Step 3: Load the GeoJSON data into a GeoDataFrame
    geo_data = gpd.read_file(response.text)

    # Step 4: Convert to a Pandas DataFrame if you don’t need geometry
    df = pd.DataFrame(geo_data.drop(columns='geometry'))  # remove geometry if not needed
    print("Data successfully converted to a DataFrame!")
else:
    print(f"Failed to fetch data. Status code: {response.status_code}")
# Out:
# Data fetched successfully!
# Data successfully converted to a DataFrame!

# %%
df.head(10)
# Out:
#    OBJECTID  DOCUMENT_NBR CRASH_YEAR       CRASH_DT CRASH_MILITARY_TM  \
# 0         1     163465085       2016  1480982400000               700
# 1         2     160725125       2016  1453766400000              1636
# 2         3     160465260       2016  1455321600000              1845
# 3         4     161255113       2016  1458950400000                 1
# 4         5     162005180       2016  1468800000000               732
# 5         6     163445154       2016  1481241600000              1112
# 6         7     161455410       2016  1463184000000              2210
# 7         8     160475530       2016  1455494400000              1945
# 8         9     162065234       2016  1469232000000              1600
# 9        10     161255184       2016  1462233600000              1415
#
#   CRASH_SEVERITY  K_PEOPLE  A_PEOPLE  B_PEOPLE  C_PEOPLE  ...  AREA_TYPE  \
# 0              O         0         0         0         0  ...      Urban
# 1              O         0         0         0         0  ...      Urban
# 2              B         0         0         2         0  ...      Rural
# 3              O         0         0         0         0  ...      Urban
# 4              O         0         0         0         0  ...      Rural
# 5              O         0         0         0         0  ...      Urban
# 6              O         0         0         0         0  ...      Urban
# 7              O         0         0         0         0  ...      Rural
# 8              O         0         0         0         0  ...      Urban
# 9              O         0         0         0         0  ...      Rural
#
#               SYSTEM  VSP                   OWNERSHIP  \
# 0    VDOT Interstate    7         1. State Hwy Agency
# 1  NonVDOT secondary    5  3. City or Town Hwy Agency
# 2     VDOT Secondary    1         1. State Hwy Agency
# 3     VDOT Secondary    1         1. State Hwy Agency
# 4       VDOT Primary    6         1. State Hwy Agency
# 5       VDOT Primary    1         1. State Hwy Agency
# 6  NonVDOT secondary    7    6. Private/Unknown Roads
# 7    VDOT Interstate    1         1. State Hwy Agency
# 8    VDOT Interstate    1         1. State Hwy Agency
# 9  NonVDOT secondary    4    6. Private/Unknown Roads
#
#                              PLAN_DISTRICT MPO_NAME  \
# 0                        Northern Virginia     NOVA
# 1                            Hampton Roads     HAMP
# 2                            Northern Neck     None
# 3                        Richmond Regional     RICH
# 4  Roanoke Valley-Alleghany, West Piedmont     None
# 5                Richmond Regional, Crater     RICH
# 6                        Northern Virginia     NOVA
# 7                        Richmond Regional     None
# 8                Richmond Regional, Crater     RICH
# 9                       Cumberland Plateau     None
#
#                        RTE_NM  RNS_MP     NODE  OFFSET
# 0            R-VA   IS00095NB  158.85     None     NaN
# 1       S-VA114NP WOODLAND RD    0.50   253154  318.32
# 2            R-VA066SC00640NB    2.54  1149141    5.82
# 3            R-VA042SC00782SB    1.19     None     NaN
# 4            R-VA   US00220NB   48.61   328737    5.34
# 5            R-VA   SR00010WB   20.22   718187  153.85
# 6  S-VA053PR GRAND CENTRAL SQ    0.19     None     NaN
# 7            R-VA   IS00064EB  162.60     None     NaN
# 8            R-VA   IS00095SB   61.24     None     NaN
# 9     S-VA083PR CAMPGROUND RD    0.03     None     NaN
#
# [10 rows x 67 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 67 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   OBJECTID                  2000 non-null   int32
#  1   DOCUMENT_NBR              2000 non-null   int32
#  2   CRASH_YEAR                2000 non-null   object
#  3   CRASH_DT                  2000 non-null   int64
#  4   CRASH_MILITARY_TM         2000 non-null   object
#  5   CRASH_SEVERITY            2000 non-null   object
#  6   K_PEOPLE                  2000 non-null   int32
#  7   A_PEOPLE                  2000 non-null   int32
#  8   B_PEOPLE                  2000 non-null   int32
#  9   C_PEOPLE                  2000 non-null   int32
#  10  PERSONS_INJURED           2000 non-null   int32
#  11  PEDESTRIANS_KILLED        2000 non-null   int32
#  12  PEDESTRIANS_INJURED       2000 non-null   int32
#  13  VEH_COUNT                 2000 non-null   int32
#  14  COLLISION_TYPE            2000 non-null   object
#  15  WEATHER_CONDITION         2000 non-null   object
#  16  LIGHT_CONDITION           2000 non-null   object
#  17  ROADWAY_SURFACE_COND      2000 non-null   object
#  18  RELATION_TO_ROADWAY       2000 non-null   object
#  19  ROADWAY_ALIGNMENT         2000 non-null   object
#  20  ROADWAY_SURFACE_TYPE      2000 non-null   object
#  21  ROADWAY_DEFECT            2000 non-null   object
#  22  ROADWAY_DESCRIPTION       2000 non-null   object
#  23  INTERSECTION_TYPE         2000 non-null   object
#  24  TRAFFIC_CONTROL_TYPE      2000 non-null   object
#  25  TRFC_CTRL_STATUS_TYPE     2000 non-null   object
#  26  WORK_ZONE_RELATED         2000 non-null   object
#  27  WORK_ZONE_LOCATION        34 non-null     object
#  28  WORK_ZONE_TYPE            34 non-null     object
#  29  SCHOOL_ZONE               2000 non-null   object
#  30  FIRST_HARMFUL_EVENT       2000 non-null   object
#  31  FIRST_HARMFUL_EVENT_LOC   2000 non-null   object
#  32  ALCOHOL_NOTALCOHOL        2000 non-null   object
#  33  ANIMAL                    2000 non-null   object
#  34  BELTED_UNBELTED           2000 non-null   object
#  35  BIKE_NONBIKE              2000 non-null   object
#  36  DISTRACTED_NOTDISTRACTED  2000 non-null   object
#  37  DROWSY_NOTDROWSY          2000 non-null   object
#  38  DRUG_NODRUG               2000 non-null   object
#  39  GR_NOGR                   2000 non-null   object
#  40  HITRUN_NOT_HITRUN         2000 non-null   object
#  41  LGTRUCK_NONLGTRUCK        2000 non-null   object
#  42  MOTOR_NONMOTOR            2000 non-null   object
#  43  PED_NONPED                2000 non-null   object
#  44  SPEED_NOTSPEED            2000 non-null   object
#  45  SPEED_DIFF_MAX            405 non-null    float64
#  46  RD_TYPE                   2000 non-null   object
#  47  INTERSECTION_ANALYSIS     2000 non-null   object
#  48  SENIOR_NOTSENIOR          2000 non-null   object
#  49  YOUNG_NOTYOUNG            2000 non-null   object
#  50  MAINLINE_YN               2000 non-null   object
#  51  NIGHT                     2000 non-null   object
#  52  VDOT_DISTRICT             2000 non-null   object
#  53  JURIS_CODE                2000 non-null   object
#  54  PHYSICAL_JURIS            2000 non-null   object
#  55  FUN                       1971 non-null   object
#  56  FAC                       1956 non-null   object
#  57  AREA_TYPE                 2000 non-null   object
#  58  SYSTEM                    2000 non-null   object
#  59  VSP                       2000 non-null   object
#  60  OWNERSHIP                 2000 non-null   object
#  61  PLAN_DISTRICT             2000 non-null   object
#  62  MPO_NAME                  1613 non-null   object
#  63  RTE_NM                    2000 non-null   object
#  64  RNS_MP                    1991 non-null   float64
#  65  NODE                      1076 non-null   object
#  66  OFFSET                    1076 non-null   float64
# dtypes: float64(3), int32(10), int64(1), object(53)
# memory usage: 968.9+ KB
